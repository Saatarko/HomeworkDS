# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img = mpimg.imread("content/matrix1.jpg")
plt.figure(figsize=(6, 6))  
plt.imshow(img)
plt.axis("off")  # Убираем оси
plt.show()

# %%
1. det(1) = 4*M1 -0*M2 + 4*M3 - 5*M4
M1 = |1 5 6|        det(M1) = 1*(6-0) -5*(6-0) + 6(2+10) =6-30+72 = 48
     |2 2 0|
     |-5 1 3|
M2 = умножается на 0
M3 = |0 1 6|           det(M3) = 0*(6-0) -1*(-6-0) + 6*(10-2) = 0+6+48=54
     |-2 2 0|
     |1 -5 3|
M4 = |0 1 5|        det(M4)   = 0*(2+10) - 1*(-2-2) + 5*(10-2) = 0+4+40=44
     |-2 2 2|
     |1 -5 1|
det(1) = 4*48-0+4*54-5*44 = 192-0+216-220= 188
# Out:
#   Cell In[1], line 1
#     1. det(1) = 4*M1 -0*M2 + 4*M3 - 5*M4
#        ^
# SyntaxError: invalid syntax

# %%
2. det(2) = 5*M1 -0*M2 + 1*M3 - 3*M4
M1 = |1 5 -1|        det(M1) = 1*(3-0) -5*(-1+6) -1(0-9) =3-25+9 = -13
     |-1 3 -2|
     |3 0 1|
M2 = умножается на 0
M3 = |0 1 -1|           det(M3) = 0*(-1-6) -1*(7+10) - 1*(21+5) = 0-17-26=-43
     |7 -1 2|
     |5 3 1|
M4 = |0 1 5|        det(M4)   = 0*(0-9) - 1*(0-15) + 5*(21+5) = 0+15+130=145
     |7 -1 3|
     |5 3 0|
det(2) = -5*13-0-1*43-3*145 = -65-0 -43 -435= -543
# Out:
#   Cell In[2], line 1
#     2. det(2) = 5*M1 -0*M2 + 1*M3 - 3*M4
#        ^
# SyntaxError: invalid syntax

# %%
3. det(3) = 4*M1 -0*M2 + 1*M3 - 5*M4
M1 = |1 0 4|        det(M1) = 1*(1-5) -0*(1+20) +4(1+4) =-4-0+20 = 16
     |1 1 5|
     |-4 1 1|
M2 = умножается на 0
M3 = |1 1 4|           det(M3) = 1*(1+20) -1*(0-30) +4*(0-6) = 21+30-24=27
     |0 1 5|
     |6 -4 1|
M4 = |1 1 0|        det(M4)   = 1*(1+4) - 1*(0-6) + 0(0+6) = 5 +6 +0=11
     |0 1 1|
     |6 -4 1|
det(3) = 4*16-0+1*27-5*11 = 64-0+27-55= 36
# Out:
#   Cell In[3], line 1
#     3. det(3) = 4*M1 -0*M2 + 1*M3 - 5*M4
#        ^
# SyntaxError: invalid syntax

# %%
7. det(7) = 3*M1 -2*M2 + 0*M3 - 1*M4
M1 = |2 2 3|        det(M1) = 2*(12-3) - 2*(10-0) + 3*(15-0) = 18-20+45 = 43
     |5 6 1|
     |0 3 2|
M2 = |0 2 3|           det(M2) = 0*(12-3) - 2*(2+2) + 3*(3+12) = 0-8+45=37
     |1 6 1|
     |-2 3 2|
M3 умножается на 0
M4 = |0 2 2|        det(M4)   = 0*(15-0) - 2*(3+12) +2*(0+10) = 0-30+20 = -10
     |1 5 6|
     |-2 0 3|
det(7) = 3*43 - 2*37 + 0 +10 = 129 - 74+0+10= 65
# Out:
#   Cell In[4], line 1
#     7. det(7) = 3*M1 -2*M2 + 0*M3 - 1*M4
#        ^
# SyntaxError: invalid syntax

# %%
8. det(8) = 5*M1 -1*M2 + 3*M3 - 0*M4
M1 = |0 5 2|        det(M1) = 0*(-7-0) -5*(7-15) +2*(0+5) =0 +40 +10=50
     |1 -1 3|
     |5 0 7|
M2 = |-3 5 2|           det(M2) = -3*(-7-0) -5*(14-3) +2*(0+1) = 21-55+2 =-32
     |2 -1 3|
     |1 0 7|
M3 = |-3 0 2|        det(M3)   = -3*(7-15) -0*(14-3) +2*(10-1) = 24-0+18=42
     |2 1 3|
     |1 5 7|
M4 = умножается на 0
det(8) = 5*50+1*32+3*42-0=250+32+126-0=408
# Out:
#   Cell In[5], line 1
#     8. det(8) = 5*M1 -1*M2 + 3*M3 - 0*M4
#        ^
# SyntaxError: invalid syntax

# %%
9. det(9) = 7*M1 -6*M2 + 0*M3 - 1*M4
M1 = |3 5 0|        det(M1) = 3*(-6-8) -5*(3-4) + 0*(2+2) = -42+5+0=-37
     |1 -2 4|
     |1 2 3|
M2 = |1 5 0|           det(M2) = 1*(-6-8) -5*(0-4)+0=-14+20=6
     |0-2 4|
     |1 2 3|
M3 = умножается на 0
M4 = |1 3 5|        det(M4)   = 1*(2+2) -3*(0+2) + 5*(0-1) = 4-6-5=-7
     |0 1 -2|
     |1 1 2|
det(9) = 7*(-37) - 6 *6 +0 - 1*(-7) = -259-36+0+7=-288
# Out:
#   Cell In[6], line 1
#     9. det(9) = 7*M1 -6*M2 + 0*M3 - 1*M4
#        ^
# SyntaxError: invalid syntax

# %%
13. det(13) = 2*M1 -3*M2 + 0*M3 - 1*M4
M1 = |0 3 1|        det(M1) = 0 -3*(-16-15) +1*(32-21) = 93+11=104
     |8 7 5|
     |3 4 -2|
M2 = |-4 3 1|           det(M2) = -4*(-14-20) -3*(0-15)+1*(0-21) = 136+45-21=160
     |0 7 5|
     |3 4 -2|
M3 = умножается на 0
M4 = |-4 0 3|        det(M4)   = -4*(32-21) - 0 + 3*(0-24)=-44-72=-116
     |0 8 7|
     |3 3 4|
det(13) = 2*104-3*160+0+116=208-480+116=-156

# %%
14. det(14) = 3*M1 -1*M2 + 3*M3 - 1*M4
M1 = |4 2 5|        det(M1) = 4*(10-9) -2*(8-0) + 5*(12-0) = 4-16+60=48
     |4 5 3|
     |0 3 2|
M2 = |2 2 5|           det(M2) = 2*(10-9)-2*(2+3) +5*(3+5) = 2-10+40=32
     |1 5 3|
     |-1 3 2|
M3 = |2 4 5|        det(M3)   = 2*(8-0) -4*(2+3) +5*(0+4) = 16-20+20=16
     |1 4 3|
     |-1 0 2|
M4 = |2 4 2|        det(M4)   = 2*(12-0) -4*(3+5) + 2*(0+4) = 24-32+8=0
     |1 4 5|
     |-1 0 3|
det(13) = 3*48-1*32+3*16-1*24=144-32+48-0=160

# %%
15. det(14) = 7*M1 -6*M2 + 0*M3 - 1*M4
M1 = |3 5 0|        det(M1) = 3*(-6-10) -5*(3-5) +0 = -48 + 10 = -38 
     |1 -2 5|
     |1 2 3|
M2 = |1 5 0|           det(M2) = 1*(-6-10) -5*(0-5) + 0 = -16+25=9
     |0 -2 5|
     |1 2 3|
M3  умножается на 0
M4 = |1 3 5|        det(M4)   = 1*(2+2) -3*(0+2)+ 5*(0-1)=4-6-5=-7
     |0 1 -2|
     |1 1 2|
det(13) = 7*(-38) -6*9+0-3=-266 - 54 +0 +7=-313

# %%
A = np.array([
    [4, 0, 4, 5],
    [0, 1, 5, 6],
    [-2, 2, 2, 0],
    [1, -5, 1, 3]
])
B = np.array([
    [5, 0, 1, 3],
    [0, 1, 5, -1],
    [7, -1, 3, -2],
    [5, 3, 0, 1]
])
B = np.array([
    [5, 0, 1, 3],
    [0, 1, 5, -1],
    [7, -1, 3, -2],
    [5, 3, 0, 1]
])
C = np.array([
    [4, 0, 1, 5],
    [1, 1, 0, 4],
    [0, 1, 1, 5],
    [6, -4, 1, 1]
])
D = np.array([
    [3, 2, 0, 1],
    [0, 2, 2, 3],
    [1, 5, 6, 1],
    [-2, 0, 3, 2]
])
E = np.array([
    [5, 1, 3, 0],
    [-3, 0, 5, 2],
    [2, 1, -1, 3],
    [1, 5, 0, 7]
])
F = np.array([
    [7, 6, 0, 1],
    [1, 3, 5, 0],
    [0, 1, -2, 4],
    [1, 1, 2, 3]
])
J = np.array([
    [2, 3, 0, 1],
    [-4, 0, 3, 1],
    [0, 8, 7, 5],
    [3, 3, 4, -2]
])
H = np.array([
    [3, 1, 3, 1],
    [2, 4, 2, 5],
    [1, 4, 5, 3],
    [-1, 0, 3, 2]
])
K = np.array([
    [7, 6, 0, 1],
    [1, 3, 5, 0],
    [0, 1, -2, 5],
    [1, 1, 2, 3]
])
det_A = np.linalg.det(A)
det_B = np.linalg.det(B)
det_C = np.linalg.det(C)
det_D = np.linalg.det(D)
det_E = np.linalg.det(E)
det_J = np.linalg.det(J)
det_H = np.linalg.det(H)
det_K = np.linalg.det(K)
print(round(det_A), round(det_B), round(det_C), round(det_D), round(det_E), round(det_F), round(det_J), round(det_H), round(det_K))  #
# Out:
# 188 -543 36 65 408 -288 -156 160 -313

# %%
img = mpimg.imread("content/matrix2.jpg")
plt.figure(figsize=(6, 6))  
plt.imshow(img)
plt.axis("off")  # Убираем оси
plt.show()

# %%
A1 = np.array([
    [1, 2, 4],
    [7, 5, -2],
    [-2, 1, 3],

])

A2 = np.array([
    [0, 3, 4],
    [-7, 1, -2],
    [2, -1, 3],

])
A3 = np.array([
    [5, 2, 9],
    [7, 0, -2],
    [-2, 1, 6],

])
A4 = np.array([
    [1, -2, 8],
    [7, 5, -2],
    [-2, 3, 0],

])
A5 = np.array([
    [9, 2, 4],
    [7, 5, -5],
    [6, -2, 3],

])

B1 = np.array([
    [-1, 0, 3],
    [2, -6, 1],
    [-7, 1, 5],

])
B2 = np.array([
    [1, 2, 4],
    [7, 0, -2],
    [-3, -2, 5],

])
B3 = np.array([
    [1, -2, 1],
    [7, 5, -2],
    [-2, 8, 3],

])
B4 = np.array([
    [0, 2, 4],
    [1, -3, -2],
    [-2, 1, 3],

])
B5 = np.array([
    [8, 2, 4],
    [0, 1, -3],
    [-2, 1, 6],

])
C1 = np.array([
    [-2, 3],
    [4, 0],
    [7, -1],

])
C2 = np.array([
    [-3, 2],
    [0, 4],
    [-1, 7],

])
C3 = np.array([
    [-2, 3],
    [4, 5],
    [0, -1],

])
C4 = np.array([
    [0, 3],
    [5, -4],
    [7, -1],

])
C5 = np.array([
    [-2, 0],
    [4, 8],
    [1, -1],

])

# %%
2. Даны матрицы A B C
Найти: А+В, В-А, A*C, A*B*C (руками)

# %%
2.1 D = А+В
D = |1-1 2+0  4+3|   =  |0 2 7|
    |7+2 5-6 -2+1|      |9 -1 -1|
    |-2-7  1+1 3+5|     |-9 2 8|

# %%
D = B-A =B + (-A)
D = |-1-1 0-2  3-4|   =  |-2 -2 -1|
    |2-7 -6-5 1+2|       |-5 -11 3|
    |-7+2 1-1 5-3|       |-5 0 2|

# %%
D = A*C
D = |1*-2 +2*4 +4*7    1*3+2*0+4*-1|     |34 -1|
    |7*-2 +5*4 -2*7    7*3 + 5*0+2*1|  = |-8 23|
    |2*2 + 1*4 + 3*7  -2*3 + 1*0 + 3*-1| |29 -9|

# %%
D = A*B*C

E =A*B =|1*-1 +2*2 +4*(-7)   1*0+2*(-6)+4*1   1*3 +2*1 +4*5|                        |-25 -8  25|
    |7*-1 +5 *2 + (-2)*(-7)   7*0 + 5*(-6) +(-2)*1   7*3 +5*1 +(-2)*5 |  =         |17 -32  16|
    |(-2)*(-1) +1*2 + 3*(-7)    (-2)*0 + 1*(-6) +3*1     (-2) *3  + 1*1 + 3*5|     |-17  -3  10]

F =E*C = |-25*(-2) + 4*(-8) +25*7    -25*3 - 8*0 +25*(-1)  |     |193 -100|
         |17*(-2) -32*4 + 16*7     17*3 -3*0 - 10*1        |   = |-50   35|
         |-17*(-2) -3*4 + 10*7     -17*3 + 0*(-3) + 10*(-1)|     |92  -61|

# %%
2.2 D = А+В
D=  |0+1  3+2  4+4|   =  |1 5 8|
    |-7+7 1+0 -2-2|      |0 1 -4|
    |2-3 -1-2 3+5|       |-1 -3 8|

# %%
D = B-A =B + (-A)
D = |1+0  2-3  4-4|   =  |1 -1 0|
    |7+7 0-1 -2+2|      |14 -1 0|
    |-3-2 -2+1 5-3|       |-5 -1 2|

# %%
D = A*C
D = |0*(-3)+3*0 + 4*(-1)   0*2+3*4+4*7|   =  |-4  40|
    |-7*(-3)+1*0 -2*(-1)   -7*2+1*4 -2*7|    |23 -24|
    |2*(-3) -1*0 + 3*(-1)   2*2 -1*4 + 3*7|  |-9  21|

# %%
D = A*B*C

E =A*B =|0*1+3*7-3*4    1*0+2*(-6)+4*1    1*3+2*1+4*5|                               |9 -8  14|
    |(-7)*1 +1*7 + (-2)*(-3)   -7*2+1*0 + (-2)*(-2)    -7*4+1*(-2) + 4*5|  =         |6 -10  40|
    |2*1+(-1)*7+3*(-3)  2*2+ (-1)*0 + 3*(2-)  2*4+(-1)*(-2) + 3*5|                   |-14  -2  25]

F =E*C = |9*(-3) + (-8)*0 + 14*(-1)    9*2 + (-8)*4+ 14 *7|           |-41   84|
         |6*(-3)+(-10)*0 + 40*(-1)    6*2+ (-10)*4 + 40*7|   =        | 22 -308|
         |(-14)*(-3) + (-2)*0 + 25*(-1)    -14*2 + (-2)*4 + 25*7|     |17  139|

# %%
2.3 D = А+В
D=  |5+1  2-2  9+1|   =   |6 0 10|
    |7+7  0+5  -2-2|      |14 5 -4|
    |-2-2 1+8  6+3|       |-4 9 9|

# %%
D = B-A =B + (-A)
D = |1-5  -2-2  1-9|   =  |-4 -4 -8|
    |7-7 5-0 -2+2|        |0 5 0|
    |-2+2 8-1 3-6|        |0 7 -3|

# %%
D = A*C
D = |0*(-3)+3*0 + 4*(-1)   0*2+3*4+4*7|   =  |-2  16|
    |-7*(-3)+1*0 -2*(-1)   -7*2+1*4 -2*7|    |-14  23|
    |2*(-3) -1*0 + 3*(-1)   2*2 -1*4 + 3*7|  | 8  -7|

# %%
D = A*B*C

E =A*B =|5*1+2*7+9*(2)   5*(-2)+2*8 + 9*8    5*1+2*(-2)9*3|                 |1  72  28|
    |7*1+0*7+(-2)*(-2)   7*(-2)+0*5 + (-2)*8  7*1+0*(-2)+(-2)*3|  =         |11 -30   1|
    |(-2)*1+1*+6*(-2)   (-2)*(-2)+1*5+6*8   -2*1+1*(-2)+6*3|                |-7  57  14]

F =E*C = |1*(-2)+72*4+28*0      1*3+72*5+28*(-1)|               |286  335|
         |11*(-2)+(-30)*4+1*0   11*3+(-30)*5+1*(-1)|   =        |-142 -118|
         |-7*(-2)+57*4+(-7)*0   -7*3+57*5+14*(-1) |             |242  250|

# %%
2.4 D = А+В
D=  |1+0  -2+2  8+4|   =   |1 0 12|
    |7+1  5-3   -2-2|      |8 2 -4|
    |-2-2  3+1  0+3|       |-4 4 3|

# %%
D = B-A =B + (-A)
D = |0-1   2+2   4-8|   =  |-1 4 -4|
    |1-7   -3-5  -2+2|      |-6 -8 0|
    |-2+2  1-3   3-0|       |0 -2 3|

# %%
D = A*C
D = |1*0+(-2)*5+8*7   1*3+(-2)*(-4)+8*(-1)|   |46   3|
    |7*0+5*5+(-2)*7   7*3+5*(-4)+(2)*(-1)|  = |11   3|
    |(-2)*0+3*5+0*7   (-2)*+3*(-4)+0*(-1)|    | 15 -18|

# %%
D = A*B*C

E =A*B =|1*0+(-2)*1+8*(-2)  1*2+(-2)*(-3) +8*1   1*4+(-2)*(-2)+8*3|            |-18  16  32|
    |7*0+5*1+(-2)*(-2)    7*2+5*(-3)+(-2)*1      7*4+5*(-2)+(-2)*3|  =         |9  -3  12|
    |-2*0+3*1+0   -2*2+3*(-3)   -2*4+3*(-2)|                                   | 3 -13 -14]

F =E*C = |-18*0+16*5+32*7   -18*3 + 16*(-4) + 32*(-1) |               |304 -150|
         |9*0 +(-3)*5+12*7   9*3 + (-3)*(-4) + 12*(-1)|   =           |69   27|
         |3*0+(-13)*5+(-14)*7   3*3+(-13)*(-4)+(-14)*(-1)|            |-163   75|

# %%
2.5 D = А+В
D=  |9+8  2+2  4+4|   =   |17 4 8|
    |7+0  5+1  -5-3|      |7 6 -8|
    |6-2  -2+1  3+6|      |-4 -1 9|

# %%
D = B-A =B + (-A)
D = |8-9  2-2  4-4|   =  |-1 0 0|
    |0-7  1-5  -3+5|     |-7 -4 2|
    |-2-6  1+2  6-3|     |-8 3 3|

# %%
D = A*C
D = |9*(-2)+2*4 + 4*1    9*0+2*8+4*(-1)|       |-6  12|
    |7*(-2)+5*4+(-5)*1   7*0+5*5+(-5)*(-1)|  = |1  45|
    |6*(-2)+(-2)*4+3*1   6*0+(-2)*8+3*(-1)|    |-17 -19|

# %%
D = A*B*C

E =A*B =|9*8+2*0+4*(-2)    9*2+2*1+4*1    9*4+2*(-3)+4*6|            |64  24  54|
    |7*8+5*0+(-5)*(-2)     7*2+5*1+(-5)*1  7*4+5*(-3)+(-5)*6|  =     |66  14 -17|
    |6*8+(-2)*0+3*(-2)    6*2+(-2)*1+3*1   6*4+(-2)*(-3)+3*6|        |42  13  48]

F =E*C = |64*(-2)+24*4+54*1     64*0+24*8+54*(-1)|            |22 138|
         |66*(-2)+14*4+(-17)*1  66*0+14*8+(-17)*(-1)|   =     |-93 129|
         |42*(-2)+13*4+48*1     42*0+13*8+48*(-1)|            |16  56|

# %%
3. Даны матрицы A B C
Найти: А+В, В-А, A*C, A*B*C (кодом)

# %%
# 2.1
print(A1+B1)
print(B1-A1)
print(A1@C1)
print(A1@B1)
print(A1@B1@C1)
# Out:
# [[ 0  2  7]
#  [ 9 -1 -1]
#  [-9  2  8]]
# [[ -2  -2  -1]
#  [ -5 -11   3]
#  [ -5   0   2]]
# [[34 -1]
#  [-8 23]
#  [29 -9]]
# [[-25  -8  25]
#  [ 17 -32  16]
#  [-17  -3  10]]
# [[ 193 -100]
#  [ -50   35]
#  [  92  -61]]

# %%
print(A2+B2)
print(B2-A2)
print(A2@C2)
print(A2@B2)
print(A2@B2@C2)
# Out:
# [[ 1  5  8]
#  [ 0  1 -4]
#  [-1 -3  8]]
# [[ 1 -1  0]
#  [14 -1  0]
#  [-5 -1  2]]
# [[ -4  40]
#  [ 23 -24]
#  [ -9  21]]
# [[  9  -8  14]
#  [  6 -10 -40]
#  [-14  -2  25]]
# [[ -41   84]
#  [  22 -308]
#  [  17  139]]

# %%
print(A3+B3)
print(B3-A3)
print(A3@C3)
print(A3@B3)
print(A3@B3@C3)
# Out:
# [[ 6  0 10]
#  [14  5 -4]
#  [-4  9  9]]
# [[-4 -4 -8]
#  [ 0  5  0]
#  [ 0  7 -3]]
# [[ -2  16]
#  [-14  23]
#  [  8  -7]]
# [[  1  72  28]
#  [ 11 -30   1]
#  [ -7  57  14]]
# [[ 286  335]
#  [-142 -118]
#  [ 242  250]]

# %%
print(A4+B4)
print(B4-A4)
print(A4@C4)
print(A4@B4)
print(A4@B4@C4)
# Out:
# [[ 1  0 12]
#  [ 8  2 -4]
#  [-4  4  3]]
# [[-1  4 -4]
#  [-6 -8  0]
#  [ 0 -2  3]]
# [[ 46   3]
#  [ 11   3]
#  [ 15 -18]]
# [[-18  16  32]
#  [  9  -3  12]
#  [  3 -13 -14]]
# [[ 304 -150]
#  [  69   27]
#  [-163   75]]

# %%
print(A5+B5)
print(B5-A5)
print(A5@C5)
print(A5@B5)
print(A5@B5@C5)
# Out:
# [[17  4  8]
#  [ 7  6 -8]
#  [ 4 -1  9]]
# [[-1  0  0]
#  [-7 -4  2]
#  [-8  3  3]]
# [[ -6  12]
#  [  1  45]
#  [-17 -19]]
# [[ 64  24  54]
#  [ 66  14 -17]
#  [ 42  13  48]]
# [[ 22 138]
#  [-93 129]
#  [ 16  56]]
